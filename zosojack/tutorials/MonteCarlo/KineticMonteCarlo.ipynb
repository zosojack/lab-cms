# %% [markdown]
# # **Simulazioni kinetic Monte Carlo con il modulo CMS**

# %% [markdown]
# ---

# %% [markdown]
# ## Teoria: come funziona la KMC?

# %% [markdown]
# ---

# %% [markdown]
# ## Quali sono i parametri che servono alla classe KineticMonteCarlo?

# %% [markdown]
# ---

# %% [markdown]
# ## Come si usa la classe KineticMonteCarlo?

# %% [markdown]
# `KineticMonteCarlo.run()` e finisce lì

# %% [markdown]
# ---

# %% [markdown]
# ## Un risultato KinteticMonteCarloResult
